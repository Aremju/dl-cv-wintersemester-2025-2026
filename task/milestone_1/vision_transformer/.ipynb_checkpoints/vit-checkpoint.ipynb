# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
import tensorflow as tf
from transformers import ViTForImageClassification, ViTImageProcessor, Trainer, TrainingArguments
from torchvision.transforms import v2
# Out:
# 2025-11-06 18:51:34.147191: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-06 18:51:34.191463: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-06 18:51:35.204124: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
train_ds = load_dataset("../../../data/animal_images/Training Data")['train']
val_ds = load_dataset("../../../data/animal_images/Training Data")['train']
# Out:
# Resolving data files:   0%|          | 0/38457 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/38457 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Resolving data files:   0%|          | 0/38457 [00:00<?, ?it/s]

# %%
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')
processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224', do_rescale = False, return_tensors = 'pt')
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def transform(example_batch):
    # Take a list of PIL images and turn them to pixel values
    inputs = processor([x for x in example_batch['image']], return_tensors='pt')

    # Don't forget to include the labels!
    inputs['labels'] = example_batch['labels']
    return inputs

# %%
test = train_ds.with_transform(transform)

# %%
metric_name = "accuracy"

# Define Train Parameters
args = TrainingArguments(
    f"breed-classification",
    use_cpu = False,
    eval_strategy="steps",
    logging_steps = 100,
    learning_rate=2e-5,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=15,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model=metric_name,
    logging_dir='logs',
    remove_unused_columns=False,
)

# Train
trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=train_ds,
    # compute_metrics=compute_metrics,
    tokenizer=processor,
)

trainer.train()
# Out:
# /tmp/ipykernel_429336/3968047774.py:21: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 30
#      20 # Train
#      21 trainer = Trainer(
#      22     model,
#      23     args,
#    (...)     27     tokenizer=processor,
#      28 )
# ---> 30 trainer.train()
#
# File /opt/conda/lib/python3.12/site-packages/transformers/trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File /opt/conda/lib/python3.12/site-packages/transformers/trainer.py:2623, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2621 update_step += 1
#    2622 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2623 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches, args.device)
#    2624 # Store the number of batches for current gradient accumulation
#    2625 # This is used to correctly scale the loss when the last accumulation step has fewer batches
#    2626 self.current_gradient_accumulation_steps = len(batch_samples)
#
# File /opt/conda/lib/python3.12/site-packages/transformers/trainer.py:5581, in Trainer.get_batch_samples(self, epoch_iterator, num_batches, device)
#    5579 for _ in range(num_batches):
#    5580     try:
# -> 5581         batch_samples.append(next(epoch_iterator))
#    5582     except StopIteration:
#    5583         break
#
# File /opt/conda/lib/python3.12/site-packages/accelerate/data_loader.py:567, in DataLoaderShard.__iter__(self)
#     565 # We iterate one batch ahead to check when we are at the end
#     566 try:
# --> 567     current_batch = next(dataloader_iter)
#     568 except StopIteration:
#     569     self.end()
#
# File /opt/conda/lib/python3.12/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File /opt/conda/lib/python3.12/site-packages/torch/utils/data/dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File /opt/conda/lib/python3.12/site-packages/datasets/arrow_dataset.py:2781, in Dataset.__getitems__(self, keys)
#    2779 def __getitems__(self, keys: list) -> list:
#    2780     """Can be used to get a batch using a list of integers indices."""
# -> 2781     batch = self.__getitem__(keys)
#    2782     n_examples = len(batch[next(iter(batch))])
#    2783     return [{col: array[i] for col, array in batch.items()} for i in range(n_examples)]
#
# File /opt/conda/lib/python3.12/site-packages/datasets/arrow_dataset.py:2777, in Dataset.__getitem__(self, key)
#    2775 def __getitem__(self, key):  # noqa: F811
#    2776     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2777     return self._getitem(key)
#
# File /opt/conda/lib/python3.12/site-packages/datasets/arrow_dataset.py:2762, in Dataset._getitem(self, key, **kwargs)
#    2760 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2761 pa_subtable = query_table(self._data, key, indices=self._indices)
# -> 2762 formatted_output = format_table(
#    2763     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2764 )
#    2765 return formatted_output
#
# File /opt/conda/lib/python3.12/site-packages/datasets/formatting/formatting.py:653, in format_table(table, key, formatter, format_columns, output_all_columns)
#     651 python_formatter = PythonFormatter(features=formatter.features)
#     652 if format_columns is None:
# --> 653     return formatter(pa_table, query_type=query_type)
#     654 elif query_type == "column":
#     655     if key in format_columns:
#
# File /opt/conda/lib/python3.12/site-packages/datasets/formatting/formatting.py:410, in Formatter.__call__(self, pa_table, query_type)
#     408     return self.format_column(pa_table)
#     409 elif query_type == "batch":
# --> 410     return self.format_batch(pa_table)
#
# File /opt/conda/lib/python3.12/site-packages/datasets/formatting/formatting.py:536, in CustomFormatter.format_batch(self, pa_table)
#     534 batch = self.python_arrow_extractor().extract_batch(pa_table)
#     535 batch = self.python_features_decoder.decode_batch(batch)
# --> 536 return self.transform(batch)
#
# Cell In[4], line 3, in transform(example_batch)
#       1 def transform(example_batch):
#       2     # Take a list of PIL images and turn them to pixel values
# ----> 3     inputs = processor([x for x in example_batch['image']], return_tensors='pt')
#       5     # Don't forget to include the labels!
#       6     inputs['labels'] = example_batch['labels']
#
# File /opt/conda/lib/python3.12/site-packages/transformers/image_processing_utils.py:51, in BaseImageProcessor.__call__(self, images, **kwargs)
#      49 def __call__(self, images, **kwargs) -> BatchFeature:
#      50     """Preprocess an image or a batch of images."""
# ---> 51     return self.preprocess(images, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/transformers/utils/generic.py:830, in filter_out_non_signature_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     821         cls_prefix = ""
#     823     warnings.warn(
#     824         f"The following named arguments are not valid for `{cls_prefix}{func.__name__}`"
#     825         f" and were ignored: {invalid_kwargs_names}",
#     826         UserWarning,
#     827         stacklevel=2,
#     828     )
# --> 830 return func(*args, **valid_kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/transformers/models/vit/image_processing_vit.py:260, in ViTImageProcessor.preprocess(self, images, do_resize, size, resample, do_rescale, rescale_factor, do_normalize, image_mean, image_std, return_tensors, data_format, input_data_format, do_convert_rgb)
#     253     logger.warning_once(
#     254         "It looks like you are trying to rescale already rescaled images. If the input"
#     255         " images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again."
#     256     )
#     258 if input_data_format is None:
#     259     # We assume that all images have the same channel dimension format.
# --> 260     input_data_format = infer_channel_dimension_format(images[0])
#     262 if do_resize:
#     263     images = [
#     264         self.resize(image=image, size=size_dict, resample=resample, input_data_format=input_data_format)
#     265         for image in images
#     266     ]
#
# File /opt/conda/lib/python3.12/site-packages/transformers/image_utils.py:339, in infer_channel_dimension_format(image, num_channels)
#     337 elif image.shape[last_dim] in num_channels:
#     338     return ChannelDimension.LAST
# --> 339 raise ValueError("Unable to infer channel dimension format")
#
# ValueError: Unable to infer channel dimension format
